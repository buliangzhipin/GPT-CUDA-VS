# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
a1 = cv2.imread("img1_small.pgm",1)

# %%
pts1 = np.float32([[0.549308,-0.138321,-5.69697],[0.13617,0.55018,0.324739],[-1.28097e-05,3.32256e-05,1]])

# %%
dst = cv2.warpPerspective(a1,pts1,(a1.shape[1],a1.shape[0]))

# %%
a1.shape
# Out:
# (272, 340, 3)

# %%
plt.imshow(a1)

# %%
a2 = cv2.imread("img2_small2.pgm",1)

# %%
plt.imshow(a2)

# %%
M = np.linalg.inv(pts1)

# %%
dst = cv2.warpPerspective(a2,M,(int(a2.shape[1]/2),int(a2.shape[0]/2)))

# %%
plt.imshow(dst)

# %%
plt.imshow(a1)

# %%
a3 = cv2.imread("img3_small2.pgm",1)
plt.imshow(a3)

# %%
plt.imshow(a1)

# %%
pts2 = np.float32([[0.522942,-0.435971,-0.417997],[0.435075,0.523927,-0.491894],[-2.10871e-06,2.40228e-05,1]])
dst = cv2.warpPerspective(a3,pts2,(int(a3.shape[0]/2),int(a3.shape[1]/2)))
plt.imshow(dst)

# %%
a4 = cv2.imread("img4_small2.pgm",1)
plt.imshow(a4)

# %%
pts3 = np.float32([[0.165174,-0.920089,-0.269842],[0.91924,0.167283,-0.552748],[4.82488e-05,5.92569e-05,1]])
# M = np.linalg.inv(pts3)
dst = cv2.warpPerspective(a4,pts3,(int(a4.shape[1]),int(a4.shape[0])))
plt.imshow(dst)
